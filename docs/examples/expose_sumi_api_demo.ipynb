# %% [markdown]
# # Expose and Sumi API Demonstration
#
# This notebook demonstrates how to interact with the Kodosumi Expose and Sumi APIs.
#
# **Prerequisites:**
# - Kodosumi server running at `http://localhost:3370`
# - Valid admin credentials

# %%
import httpx
import time
from pprint import pprint

# %%
# Configuration
BASE_URL = "http://localhost:3370"

USERNAME = "admin"
PASSWORD = "admin"

# %% [markdown]
# ## Login
#
# First, we need to authenticate with the Kodosumi server to obtain a session.

# %%
# Create HTTP client with session support
client = httpx.Client(base_url=BASE_URL, follow_redirects=True, timeout=30.0)

# Perform login
login_resp = client.post(
    "/login",
    data={"name": USERNAME, "password": PASSWORD},
    headers={"Content-Type": "application/x-www-form-urlencoded"}
)

print(f"Login status: {login_resp.status_code}")
assert login_resp.status_code == 200, f"Login failed: {login_resp.text}"
print("Login successful!")
# Out:
# Login status: 200
# Login successful!

# %% [markdown]
# ## Ensure Expose is Empty
#
# > **"Be careful with that axe, Eugene"**
# >
# > The following cells will **DELETE ALL** expose items from your database.
# > This is a destructive operation. Only proceed if you understand what you're doing.

# %%
# List current exposes
resp = client.get("/expose/")
print(f"Status: {resp.status_code}")

exposes = resp.json()
print(f"Found {len(exposes)} expose(s):")
for expose in exposes:
    print(f"  - {expose['name']} (state: {expose.get('state', 'N/A')})")
# Out:
# Status: 200
# Found 4 expose(s):
#   - form-example (state: RUNNING)
#   - jkx (state: RUNNING)
#   - prime (state: RUNNING)
#   - sumi-test (state: RUNNING)

# %%
# Delete all exposes (if any exist)
if exposes:
    print(f"Deleting {len(exposes)} expose(s)...")
    for expose in exposes:
        name = expose['name']
        del_resp = client.delete(f"/expose/{name}")
        if del_resp.status_code == 204:
            print(f"  Deleted: {name}")
        else:
            print(f"  Failed to delete {name}: {del_resp.status_code} - {del_resp.text}")
    print("Done.")
else:
    print("No exposes to delete.")
# Out:
# Deleting 4 expose(s)...
#   Deleted: form-example
#   Deleted: jkx
#   Deleted: prime
#   Deleted: sumi-test
# Done.

# %%
# Verify expose list is empty
resp = client.get("/expose/")
exposes = resp.json()

assert len(exposes) == 0, f"Expected 0 exposes, got {len(exposes)}"
print("Verified: Expose list is empty.")
# Out:
# Verified: Expose list is empty.

# %% [markdown]
# ### shutdown

# %%
# Shutdown Ray Serve (streaming response)
with client.stream("DELETE", "/boot/") as resp:
    print(f"Shutdown status: {resp.status_code}")
    for line in resp.iter_lines():
        if line:
            print(line)
# Out:
# Shutdown status: 200
# ▶ [DEPLOY] Shutting down Ray Serve
#   • [serve] Running serve shutdown -y
#   serve shutdown → success
# ▶ [UPDATE] Updating expose states
#   • [Clearing flow registry] PUT /flow/register
#   Flow registry refreshed → 0 flows remaining
# ✔ Shutdown complete

# %% [markdown]
# ## Create Exposes
#
# Now we'll create 4 expose items via `POST /expose/`.

# %%
# 1) Create expose: jkx
resp = client.post("/expose/", json={
    "name": "jkx",
    "bootstrap": "import_path: tests.test_unwrap:fast_app2"
})
print(f"jkx: {resp.status_code}")
pprint(resp.json())
# Out:
# jkx: 201
# {'bootstrap': 'import_path: tests.test_unwrap:fast_app2',
#  'created': '2025-12-11T09:34:48.677926',
#  'display': None,
#  'enabled': True,
#  'etag': '1765442088.6779258',
#  'flow_stats': '0/0',
#  'heartbeat': 1765442088.652844,
#  'meta': None,
#  'name': 'jkx',
#  'needs_reboot': False,
#  'network': None,
#  'stale': False,
#  'state': 'DEAD',
#  'updated': '2025-12-11T09:34:48.677926'}

# %%
# 2) Create expose: form-example
resp = client.post("/expose/", json={
    "name": "form-example",
    "bootstrap": "import_path: tests.form_elements_demo:fast_app"
})
print(f"form-example: {resp.status_code}")
pprint(resp.json())
# Out:
# form-example: 201
# {'bootstrap': 'import_path: tests.form_elements_demo:fast_app',
#  'created': '2025-12-11T09:34:49.992096',
#  'display': None,
#  'enabled': True,
#  'etag': '1765442089.992096',
#  'flow_stats': '0/0',
#  'heartbeat': 1765442089.963883,
#  'meta': None,
#  'name': 'form-example',
#  'needs_reboot': False,
#  'network': None,
#  'stale': False,
#  'state': 'DEAD',
#  'updated': '2025-12-11T09:34:49.992096'}

# %%
# 3) Create expose: prime (with runtime_env and deployments)
prime_bootstrap = """import_path: kodosumi_examples.prime.app:fast_app
runtime_env:
  py_modules:
    - https://github.com//masumi-network/kodosumi-examples/archive/c1fc02b73e8fc3a1298c26b1597627098ecc7510.zip
deployments:
  - name: PrimeDistribution
    num_replicas: 1
    ray_actor_options:
      num_cpus: 0.1
"""

resp = client.post("/expose/", json={
    "name": "prime",
    "bootstrap": prime_bootstrap
})
print(f"prime: {resp.status_code}")
pprint(resp.json())
# Out:
# prime: 201
# {'bootstrap': 'import_path: kodosumi_examples.prime.app:fast_app\n'
#               'runtime_env:\n'
#               '  py_modules:\n'
#               '    - '
#               'https://github.com//masumi-network/kodosumi-examples/archive/c1fc02b73e8fc3a1298c26b1597627098ecc7510.zip\n'
#               'deployments:\n'
#               '  - name: PrimeDistribution\n'
#               '    num_replicas: 1\n'
#               '    ray_actor_options:\n'
#               '      num_cpus: 0.1\n',
#  'created': '2025-12-11T09:34:51.398918',
#  'display': None,
#  'enabled': True,
#  'etag': '1765442091.398918',
#  'flow_stats': '0/0',
#  'heartbeat': 1765442091.35711,
#  'meta': None,
#  'name': 'prime',
#  'needs_reboot': False,
#  'network': None,
#  'stale': False,
#  'state': 'DEAD',
#  'updated': '2025-12-11T09:34:51.398918'}

# %%
# 4) Create expose: sumi-test
resp = client.post("/expose/", json={
    "name": "sumi-test",
    "bootstrap": "import_path: tests.test_masumi:fast_app"
})
print(f"sumi-test: {resp.status_code}")
pprint(resp.json())
# Out:
# sumi-test: 201
# {'bootstrap': 'import_path: tests.test_masumi:fast_app',
#  'created': '2025-12-11T10:04:43.727819',
#  'display': None,
#  'enabled': True,
#  'etag': '1765443883.727819',
#  'flow_stats': '0/0',
#  'heartbeat': 1765443883.684232,
#  'meta': None,
#  'name': 'sumi-test',
#  'needs_reboot': False,
#  'network': None,
#  'stale': False,
#  'state': 'DEAD',
#  'updated': '2025-12-11T10:04:43.727819'}

# %%
# Verify: List all exposes
resp = client.get("/expose/")
exposes = resp.json()

print(f"Created {len(exposes)} expose(s):")
for expose in exposes:
    print(f"  - {expose['name']} (state: {expose.get('state', 'N/A')})")
# Out:
# Created 4 expose(s):
#   - form-example (state: DEAD)
#   - jkx (state: DEAD)
#   - prime (state: DEAD)
#   - sumi-test (state: DEAD)

# %% [markdown]
# ## Update Exposes
#
# Update `form-example` and `jkx` with display names and descriptions.

# %%
# Update form-example with display name
resp = client.post("/expose/", json={
    "name": "form-example",
    "display": "Form Elements Demo",
    "bootstrap": "import_path: tests.form_elements_demo:fast_app",
    "meta": [{
        "url": "/form-example/",
        "data": """display: Form Elements Demo
description: Showcases all available form input components
tags:
  - demo
  - forms
"""
    }]
})
print(f"form-example update: {resp.status_code}")
pprint(resp.json())
# Out:
# form-example update: 201
# {'bootstrap': 'import_path: tests.form_elements_demo:fast_app',
#  'created': '2025-12-11T09:34:49.992096',
#  'display': 'Form Elements Demo',
#  'enabled': True,
#  'etag': '1765443891.296156',
#  'flow_stats': '0/0',
#  'heartbeat': 1765443891.261945,
#  'meta': [{'data': 'display: Form Elements Demo\n'
#                    'description: Showcases all available form input '
#                    'components\n'
#                    'tags:\n'
#                    '  - demo\n'
#                    '  - forms\n',
#            'enabled': True,
#            'heartbeat': None,
#            'state': None,
#            'url': '/form-example/'}],
#  'name': 'form-example',
#  'needs_reboot': False,
#  'network': None,
#  'stale': False,
#  'state': 'DEAD',
#  'updated': '2025-12-11T10:04:51.296156'}

# %%
# Update jkx with display name
resp = client.post("/expose/", json={
    "name": "jkx",
    "display": "jKx Demo",
    "bootstrap": "import_path: tests.test_unwrap:fast_app2",
    "meta": [{
        "url": "/jkx/",
        "data": """display: JKX Unwrap Test
description: Tests response unwrapping functionality
tags:
  - test
  - unwrap
"""
    }]
})
print(f"jkx update: {resp.status_code}")
pprint(resp.json())
# Out:
# jkx update: 201
# {'bootstrap': 'import_path: tests.test_unwrap:fast_app2',
#  'created': '2025-12-11T09:34:48.677926',
#  'display': 'jKx Demo',
#  'enabled': True,
#  'etag': '1765443899.183554',
#  'flow_stats': '0/0',
#  'heartbeat': 1765443899.156683,
#  'meta': [{'data': 'display: JKX Unwrap Test\n'
#                    'description: Tests response unwrapping functionality\n'
#                    'tags:\n'
#                    '  - test\n'
#                    '  - unwrap\n',
#            'enabled': True,
#            'heartbeat': None,
#            'state': None,
#            'url': '/jkx/'}],
#  'name': 'jkx',
#  'needs_reboot': False,
#  'network': None,
#  'stale': False,
#  'state': 'DEAD',
#  'updated': '2025-12-11T10:04:59.183554'}

# %% [markdown]
# ## Sumi API
#
# Verify that `/sumi` returns an empty list before boot, then boot and verify flows are available.

# %%
# Verify /sumi returns empty list (before boot)
resp = client.get("/sumi")
data = resp.json()

print(f"Status: {resp.status_code}")
print(f"Items: {len(data.get('items', []))}")
assert len(data.get('items', [])) == 0, f"Expected 0 items, got {len(data.get('items', []))}"
print("Verified: /sumi returns empty list (no boot yet)")
# Out:
# Status: 200
# Items: 0
# Verified: /sumi returns empty list (no boot yet)

# %%
# Boot Ray Serve (streaming response)
with client.stream("POST", "/boot/") as resp:
    print(f"Boot status: {resp.status_code}")
    for line in resp.iter_lines():
        if line:
            print(line)
# Out:
# Boot status: 201
# ℹ Boot started at 2025-12-11 10:05:03
# ▶ [DEPLOY] Starting Ray Serve deployment
#   • [serve_config.yaml] Loading global configuration → OK
#   • [form-example] Prepared deployment config → route=/form-example
#   • [jkx] Prepared deployment config → route=/jkx
#   • [prime] Prepared deployment config → route=/prime
#   • [sumi-test] Prepared deployment config → route=/sumi-test
#   • [/var/folders/n9/f3p_gzsj7vjfgfw70yqksywcn5rfs9/T/serve_deploy_idbslp1l.yaml] Created merged deployment config
#   • [serve] Running serve deploy (4 applications)
#   serve deploy command → success
# ✓ Deployment initiated (4 applications)
# ▶ [HEALTH] Waiting for deployments to complete (timeout: 1800s)
#   • [form-example] Status: DEPLOYING
#   • [jkx] Status: DEPLOYING
#   • [prime] Status: DEPLOYING
#   • [sumi-test] Status: DEPLOYING
#   [form-example] Reached final state → RUNNING
#   [jkx] Reached final state → RUNNING
#   [sumi-test] Reached final state → RUNNING
#   [prime] Reached final state → RUNNING
# ✓ All deployments complete (4 running, 0 failed)
# ▶ [REGISTER] Registering flow endpoints
#   • POST http://localhost:3370/flow/register → http://localhost:8005/-/routes
#   Registered 10 flow(s) via /-/routes → None
#   • [form-example] Discovered 6 flow endpoint(s) → text-inputs, numeric-inputs, datetime-inputs, selection-inputs, special-inputs, complete-form
#   • [jkx] Discovered 1 flow endpoint(s) → serve
#   • [sumi-test] Discovered 1 flow endpoint(s)
#   • [prime] Discovered 2 flow endpoint(s) → , async
# ✓ Flow registration complete (10 registered, 10 discovered)
# ▶ [RETRIEVE] Testing flow endpoints
#   • [form-example] Checking 6 endpoint(s)
#   • [jkx] Checking 1 endpoint(s)
#   • [sumi-test] Checking 1 endpoint(s)
#   • [prime] Checking 2 endpoint(s)
#   [form-example] HEAD /form-example/text-inputs → 200 OK (alive)
#   [form-example] HEAD /form-example/numeric-inputs → 200 OK (alive)
#   [form-example] HEAD /form-example/datetime-inputs → 200 OK (alive)
#   [form-example] HEAD /form-example/selection-inputs → 200 OK (alive)
#   [form-example] HEAD /form-example/special-inputs → 200 OK (alive)
#   [form-example] HEAD /form-example/complete-form → 200 OK (alive)
#   [jkx] HEAD /jkx/serve → 200 OK (alive)
#   [sumi-test] HEAD /sumi-test/ → 200 OK (alive)
#   [prime] HEAD /prime/ → 200 OK (alive)
#   [prime] HEAD /prime/async → 200 OK (alive)
# ✓ Retrieved 10 flow endpoints (10 alive, 0 dead)
# ▶ [UPDATE] Updating expose metadata
#   • [GET /flow] Fetching registered flows
#   Retrieved flows → 10 flows
#   • [form-example] Processing 6 flow(s)
#   [form-example] Updated meta → 6 new, 0 preserved
#   • [sumi-test] Processing 1 flow(s)
#   [sumi-test] Updated meta → 1 new, 0 preserved
#   • [prime] Processing 2 flow(s)
#   [prime] Updated meta → 2 new, 0 preserved
#   • [jkx] Processing 1 flow(s)
#   [jkx] Updated meta → 1 new, 0 preserved
# ✓ Metadata update complete (10 new, 0 preserved, 10 alive)
# ✔ Boot completed at 2025-12-11 10:05:20 (runtime: 16.2s)

# %%
# Verify /sumi returns flows after boot
resp = client.get("/sumi")
data = resp.json()

print(f"Status: {resp.status_code}")
items = data.get('items', [])
print(f"Found {len(items)} flow(s):")
for item in items:
    print(f"  - {item.get('display', 'N/A')} ({item.get('api_url', 'N/A')})")

assert len(items) > 0, "Expected flows after boot"
print(f"\nVerified: /sumi returns {len(items)} flows after boot")
# Out:
# Status: 200
# Found 10 flow(s):
#   - Complete Registration Form (http://localhost:3370/sumi/form-example/complete-form)
#   - Date/Time Input Types Demo (http://localhost:3370/sumi/form-example/datetime-inputs)
#   - Numeric Input Types Demo (http://localhost:3370/sumi/form-example/numeric-inputs)
#   - Selection Input Types Demo (http://localhost:3370/sumi/form-example/selection-inputs)
#   - Special Input Types Demo (http://localhost:3370/sumi/form-example/special-inputs)
#   - Text Input Types Demo (http://localhost:3370/sumi/form-example/text-inputs)
#   - jKx Knowledge Graph (http://localhost:3370/sumi/jkx/serve)
#   - Prime Gap Distribution (http://localhost:3370/sumi/prime)
#   - Prime Gap Distribution (async) (http://localhost:3370/sumi/prime/async)
#   - Masumi Two-Stage Service (http://localhost:3370/sumi/sumi-test)
#
# Verified: /sumi returns 10 flows after boot

# %% [markdown]
# ## Text Inputs Demo
#
# Demonstrate starting a job on the `text-inputs` flow and checking its status.

# %%
# Get input schema for text-inputs flow
resp = client.get("/sumi/form-example/text-inputs/input_schema")

print(f"Status: {resp.status_code}")
print("Input Schema:")
pprint(resp.json())
# Out:
# Status: 200
# Input Schema:
# {'input_data': [{'data': {'placeholder': 'Enter your username (3-20 chars)'},
#                  'id': 'username',
#                  'name': 'Username',
#                  'type': 'text',
#                  'validations': {'max': '20'}},
#                 {'data': {'placeholder': 'Min 8 characters'},
#                  'id': 'password',
#                  'name': 'Password',
#                  'type': 'password',
#                  'validations': {'max': '100', 'min': '8'}},
#                 {'data': {'placeholder': 'user@example.com'},
#                  'id': 'email',
#                  'name': 'Email Address',
#                  'type': 'email',
#                  'validations': {'format': 'email'}},
#                 {'data': {'placeholder': 'https://example.com'},
#                  'id': 'website',
#                  'name': 'Website URL',
#                  'type': 'url',
#                  'validations': {'format': 'url', 'optional': True}},
#                 {'data': {'placeholder': '+1 (555) 123-4567'},
#                  'id': 'phone',
#                  'name': 'Phone Number',
#                  'type': 'tel',
#                  'validations': {'format': 'tel-pattern', 'optional': True}},
#                 {'data': {'placeholder': 'Type to search...'},
#                  'id': 'search_query',
#                  'name': 'Search Query',
#                  'type': 'search',
#                  'validations': {'optional': True}},
#                 {'data': {'placeholder': 'Tell us about yourself (max 500 '
#                                          'chars)'},
#                  'id': 'bio',
#                  'name': 'Biography',
#                  'type': 'textarea',
#                  'validations': {'max': '500', 'optional': True}}],
#  'input_groups': None}

# %% [markdown]
# ### Validation failed (400)

# %%
# Start a job on text-inputs
resp = client.post("/sumi/form-example/text-inputs/start_job", json={})
print(f"Status: {resp.status_code}")
result = resp.json()
pprint(result)
# Out:
# Status: 400
# {'detail': 'Validation failed for POST '
#            "/sumi/form-example/text-inputs/start_job: [{'message': 'Field "
#            "required', 'key': 'identifier_from_purchaser'}]",
#  'error': 'ValidationException',
#  'path': '/sumi/form-example/text-inputs/start_job',
#  'status_code': 400}

# %% [markdown]
# ### backend validation failed (201)

# %%
# Start a job on text-inputs
resp = client.post("/sumi/form-example/text-inputs/start_job", json={
    "identifier_from_purchaser": "demo-123"})

print(f"Status: {resp.status_code}")
result = resp.json()
pprint(result)
# Out:
# Status: 201
# {'error': "username: ['Username is required']; password: ['Password is "
#           "required']; email: ['Email is required']; _global_: []",
#  'status': 'failed'}

# %%
# Start a job on text-inputs
resp = client.post("/sumi/form-example/text-inputs/start_job", json={
    "identifier_from_purchaser": "demo-123",
    "input_data": {
        "username": "DemoUser",
    }
})

print(f"Status: {resp.status_code}")
result = resp.json()
pprint(result)
# Out:
# Status: 201
# {'error': "password: ['Password is required']; email: ['Email is required']; "
#           '_global_: []',
#  'status': 'failed'}

# %%
# Start a job on text-inputs
resp = client.post("/sumi/form-example/text-inputs/start_job", json={
    "identifier_from_purchaser": "demo-123",
    "input_data": {
        "username": "DemoUser",
        "password": "secretpass123"
    }
})

print(f"Status: {resp.status_code}")
result = resp.json()
pprint(result)
# Out:
# Status: 201
# {'error': "email: ['Email is required']; _global_: []", 'status': 'failed'}

# %% [markdown]
# ### Successful POST

# %%
# Start a job on text-inputs
resp = client.post("/sumi/form-example/text-inputs/start_job", json={
    "identifier_from_purchaser": "demo-123",
    "input_data": {
        "email": "user@example.com",
        "username": "DemoUser",
        "password": "secretpass123"
    }
})

print(f"Status: {resp.status_code}")
result = resp.json()
pprint(result)

# Save job_id for status check
job_id = result.get("job_id")
print(f"\nJob ID: {job_id}")
# Out:
# Status: 201
# {'error': None,
#  'identifier_from_purchaser': 'demo-123',
#  'input_schema': None,
#  'job_id': '693a89716dd65963058e6b2d',
#  'result': None,
#  'runtime': None,
#  'started_at': 68542.677,
#  'status': 'running',
#  'updated_at': 68542.85}
#
# Job ID: 693a89716dd65963058e6b2d

# %%
# Check job status
resp = client.get(f"/sumi/status/{job_id}")

print(f"Status: {resp.status_code}")
pprint(resp.json())
# Out:
# Status: 200
# {'error': None,
#  'identifier_from_purchaser': 'demo-123',
#  'input_schema': None,
#  'job_id': '693a89716dd65963058e6b2d',
#  'result': {'dict': {'ok': True}},
#  'runtime': 0.22410869598388672,
#  'started_at': 1765443954.287033,
#  'status': 'completed',
#  'updated_at': 1765443954.5111418}

# %% [markdown]
# ## Prime Demo
#
# Demonstrate the `prime` flow which calculates prime gap distributions.
#
# - **No input**: Should succeed with defaults (start=0, end=10000000, tasks=200)
# - **Invalid input**: Non-integer values should fail
# - **Streaming API**: Direct access via proxy (not part of Sumi protocol)

# %%
# Get input schema for prime flow
resp = client.get("/sumi/prime/input_schema")

print(f"Status: {resp.status_code}")
print("Input Schema:")
pprint(resp.json())
# Out:
# Status: 200
# Input Schema:
# {'input_data': [{'data': {'default': '0'},
#                  'id': 'start',
#                  'name': 'Start',
#                  'type': 'text',
#                  'validations': {'optional': True}},
#                 {'data': {'default': '10000000'},
#                  'id': 'end',
#                  'name': 'End',
#                  'type': 'text',
#                  'validations': {'optional': True}},
#                 {'data': {'default': '200'},
#                  'id': 'tasks',
#                  'name': 'Tasks',
#                  'type': 'text',
#                  'validations': {'optional': True}}],
#  'input_groups': None}

# %% [markdown]
# ### No input (error)

# %%
# Start job with no input_data (uses defaults)
resp = client.post("/sumi/prime/start_job", json={
    "identifier_from_purchaser": "prime-no-input"
})

print(f"Status: {resp.status_code}")
result = resp.json()
pprint(result)

prime_job_id = result.get("job_id")
print(f"\nJob ID: {prime_job_id}")
# Out:
# Status: 201
# {'error': None,
#  'identifier_from_purchaser': 'prime-no-input',
#  'input_schema': None,
#  'job_id': '693a89776dd6592cb1a867a5',
#  'result': None,
#  'runtime': None,
#  'started_at': 68548.876,
#  'status': 'running',
#  'updated_at': 68548.97}
#
# Job ID: 693a89776dd6592cb1a867a5

# %%
# Poll until job completes
max_attempts = 60
for i in range(max_attempts):
    resp = client.get(f"/sumi/status/{prime_job_id}")
    status_data = resp.json()
    job_status = status_data.get("status")

    print(f"[{i+1}/{max_attempts}] Status: {job_status}")

    if job_status in ("completed", "failed"):
        print("\nFinal result:")
        pprint(status_data)
        break

    time.sleep(1)
else:
    print("Job did not complete within timeout")
# Out:
# [1/60] Status: None
# [2/60] Status: running
# [3/60] Status: running
# [4/60] Status: failed
#
# Final result:
# {'error': 'Traceback (most recent call last):\n'
#           '  File "/Users/raum/Project/kodosumi/kodosumi/runner/main.py", line '
#           '165, in run\n'
#           '    await self.start()\n'
#           '  File '
#           '"/Users/raum/Project/kodosumi/.venv/lib/python3.12/site-packages/ray/util/tracing/tracing_helper.py", '
#           'line 493, in _resume_span\n'
#           '    return await method(self, *_args, **_kwargs)\n'
#           '           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n'
#           '  File "/Users/raum/Project/kodosumi/kodosumi/runner/main.py", line '
#           '309, in start\n'
#           '    result = await asyncio.get_event_loop().run_in_executor(\n'
#           '             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n'
#           '  File '
#           '"/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py", '
#           'line 58, in run\n'
#           '    result = self.fn(*self.args, **self.kwargs)\n'
#           '             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n'
#           '  File '
#           '"/tmp/ray/session_2025-12-11_09-33-51_216762_90610/runtime_resources/py_modules_files/https_github_com__masumi-network_kodosumi-examples_archive_c1fc02b73e8fc3a1298c26b1597627098ecc7510/kodosumi_examples/prime/app.py", '
#           'line 19, in run\n'
#           '    start = inputs.get("start", "").strip()\n'
#           '            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n'
#           "AttributeError: 'NoneType' object has no attribute 'strip'\n",
#  'identifier_from_purchaser': 'prime-no-input',
#  'input_schema': None,
#  'job_id': '693a89776dd6592cb1a867a5',
#  'result': None,
#  'runtime': 2.5231189727783203,
#  'started_at': 1765443962.278985,
#  'status': 'failed',
#  'updated_at': 1765443964.802104}

# %% [markdown]
# ### Invalid input (non-integer values - should fail)

# %%
# Start job with invalid input (non-integer values)
resp = client.post("/sumi/prime/start_job", json={
    "identifier_from_purchaser": "prime-invalid",
    "input_data": {
        "start": "not-a-number",
        "end": "also-invalid",
        "tasks": "abc"
    }
})

print(f"Status: {resp.status_code}")
result = resp.json()
pprint(result)

invalid_job_id = result.get("job_id")
# Out:
# Status: 201
# {'error': None,
#  'identifier_from_purchaser': 'prime-invalid',
#  'input_schema': None,
#  'job_id': '693a898e6dd6592cb1a867a6',
#  'result': None,
#  'runtime': None,
#  'started_at': 68572.494,
#  'status': 'running',
#  'updated_at': 68572.532}

# %%
# Check status of invalid job (should show error)
for i in range(10):
    resp = client.get(f"/sumi/status/{invalid_job_id}")
    status_data = resp.json()
    job_status = status_data.get("status")

    print(f"[{i+1}/10] Status: {job_status}")

    if job_status in ("completed", "failed"):
        print("\nFinal result:")
        pprint(status_data)
        break

    time.sleep(1)
# Out:
# [1/10] Status: None
# [2/10] Status: running
# [3/10] Status: running
# [4/10] Status: running
# [5/10] Status: failed
#
# Final result:
# {'error': 'Traceback (most recent call last):\n'
#           '  File "/Users/raum/Project/kodosumi/kodosumi/runner/main.py", line '
#           '165, in run\n'
#           '    await self.start()\n'
#           '  File '
#           '"/Users/raum/Project/kodosumi/.venv/lib/python3.12/site-packages/ray/util/tracing/tracing_helper.py", '
#           'line 493, in _resume_span\n'
#           '    return await method(self, *_args, **_kwargs)\n'
#           '           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n'
#           '  File "/Users/raum/Project/kodosumi/kodosumi/runner/main.py", line '
#           '309, in start\n'
#           '    result = await asyncio.get_event_loop().run_in_executor(\n'
#           '             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n'
#           '  File '
#           '"/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py", '
#           'line 58, in run\n'
#           '    result = self.fn(*self.args, **self.kwargs)\n'
#           '             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n'
#           '  File '
#           '"/tmp/ray/session_2025-12-11_09-33-51_216762_90610/runtime_resources/py_modules_files/https_github_com__masumi-network_kodosumi-examples_archive_c1fc02b73e8fc3a1298c26b1597627098ecc7510/kodosumi_examples/prime/app.py", '
#           'line 23, in run\n'
#           '    int(start), int(end), int(tasks), tracer)\n'
#           '    ^^^^^^^^^^\n'
#           'ValueError: invalid literal for int() with base 10: '
#           "'not-a-number'\n",
#  'identifier_from_purchaser': 'prime-invalid',
#  'input_schema': None,
#  'job_id': '693a898e6dd6592cb1a867a6',
#  'result': None,
#  'runtime': 2.7527480125427246,
#  'started_at': 1765443985.601849,
#  'status': 'failed',
#  'updated_at': 1765443988.354597}

# %% [markdown]
# ### Successful launch (valid integers)

# %%
# Start job with valid input (smaller range for faster execution)
resp = client.post("/sumi/prime/start_job", json={
    "identifier_from_purchaser": "prime-valid",
    "input_data": {
        "start": "0",
        "end": "100000",
        "tasks": "10"
    }
})

print(f"Status: {resp.status_code}")
result = resp.json()
pprint(result)

valid_job_id = result.get("job_id")
print(f"\nJob ID: {valid_job_id}")
# Out:
# Status: 201
# {'error': None,
#  'identifier_from_purchaser': 'prime-valid',
#  'input_schema': None,
#  'job_id': '693a899f6dd6592cb1a867a7',
#  'result': None,
#  'runtime': None,
#  'started_at': 68589.556,
#  'status': 'running',
#  'updated_at': 68589.598}
#
# Job ID: 693a899f6dd6592cb1a867a7

# %%
# Poll until job completes
for i in range(60):
    resp = client.get(f"/sumi/status/{valid_job_id}")
    status_data = resp.json()
    job_status = status_data.get("status")

    print(f"[{i+1}/60] Status: {job_status}")

    if job_status in ("completed", "failed"):
        print("\nFinal result:")
        pprint(status_data)
        break

    time.sleep(1)
else:
    print("Job did not complete within timeout")
# Out:
# [1/60] Status: None
# [2/60] Status: running
# [3/60] Status: running
# [4/60] Status: running
# [5/60] Status: running
# [6/60] Status: running
# [7/60] Status: running
# [8/60] Status: running
# [9/60] Status: running
# [10/60] Status: running
# [11/60] Status: running
# [12/60] Status: running
# [13/60] Status: completed
#
# Final result:
# {'error': None,
#  'identifier_from_purchaser': 'prime-valid',
#  'input_schema': None,
#  'job_id': '693a899f6dd6592cb1a867a7',
#  'result': {'dict': {'1': 1,
#                      '10': 916,
#                      '12': 964,
#                      '14': 484,
#                      '16': 339,
#                      '18': 514,
#                      '2': 1224,
#                      '20': 238,
#                      '22': 223,
#                      '24': 206,
#                      '26': 88,
#                      '28': 98,
#                      '30': 146,
#                      '32': 32,
#                      '34': 33,
#                      '36': 54,
#                      '38': 19,
#                      '4': 1215,
#                      '40': 28,
#                      '42': 19,
#                      '44': 5,
#                      '46': 4,
#                      '48': 3,
#                      '50': 5,
#                      '52': 7,
#                      '54': 4,
#                      '56': 1,
#                      '58': 4,
#                      '6': 1940,
#                      '60': 1,
#                      '62': 1,
#                      '64': 1,
#                      '72': 1,
#                      '8': 773}},
#  'runtime': 11.78423810005188,
#  'started_at': 1765444002.884925,
#  'status': 'completed',
#  'updated_at': 1765444014.669163}

# %% [markdown]
# ### Streaming API
#
# Stream execution events in real-time using the outputs endpoint.
# This uses the `valid_job_id` from the successful launch above.

# %%
# Start job with valid input (smaller range for faster execution)
resp = client.post("/sumi/prime/start_job", json={
    "identifier_from_purchaser": "prime-valid",
    "input_data": {
        "start": "0",
        "end": "100000",
        "tasks": "10"
    }
})

print(f"Status: {resp.status_code}")
result = resp.json()
pprint(result)

valid_job_id = result.get("job_id")
print(f"\nJob ID: {valid_job_id}")
# Out:
# Status: 201
# {'error': None,
#  'identifier_from_purchaser': 'prime-valid',
#  'input_schema': None,
#  'job_id': '693a89b26dd6592cb1a867a8',
#  'result': None,
#  'runtime': None,
#  'started_at': 68607.631,
#  'status': 'running',
#  'updated_at': 68607.712}
#
# Job ID: 693a89b26dd6592cb1a867a8

# %%
# Stream execution events for the valid job
# Note: This streams from a completed job, showing all recorded events
with client.stream("GET", f"/outputs/stream/{valid_job_id}?extended=true") as resp:
    print(f"Stream status: {resp.status_code}")
    print("Streaming events:")
    for line in resp.iter_lines():
        if line:
            print(line)
# Out:
# Stream status: 200
# Streaming events:
# id: 1
# event: status
# data: 1765444020.934319:starting
# id: 2
# event: inputs
# data: 1765444023.2913861:{"dict":{"start":"0","end":"100000","tasks":"10"}}
# id: 3
# event: meta
# data: 1765444023.6275892:{"dict":{"fid":"693a89b26dd6592cb1a867a8","username":"c7eb70a5-0c26-407e-b785-f1ef5e7c4486","app_url":"http://localhost:8005/prime","panel_url":"http://localhost:3370","entry_point":"kodosumi_examples.prime.app:run","kodosumi":"1.1.0","tags":["Test"],"summary":"Prime Gap Distribution","description":"This agent creates a prime gap distribution for a given range of numbers.","deprecated":null,"author":"m.rau@house-of-communication.com","organization":"House of Communication","version":"0.1.0","extra":{"identifier_from_purchaser":"prime-valid","input_hash":"5bc06e91746525903d5f5d0d9d3e0cc873df900aa033f096b68a34e08e916269","sumi_endpoint":"prime"}}}
# id: 4
# event: status
# data: 1765444023.8492749:running
# id: 0
# event: alive
# data: 1765444026.8592472:service alive
# id: 0
# event: alive
# data: 1765444029.859933:service alive
# id: 5
# event: result
# data: 1765444030.8006122:{"Markdown":{"body":"\n        ###### Job completed (2/10)\n        * range: 10000 - 19999\n        * node: 0c33869970f103f489ef84d3e6e01023e451120cab7f438ddfd8b189\n        * found 1033 primes\n\n        ```python\n        {2: 137, 28: 12, 22: 22, 6: 226, 10: 92, 12: 109, 4: 141, 8: 85, 18: 44, 20: 25, 16: 36, 14: 53, 32: 1, 24: 19, 26: 7, 34: 5, 36: 4, 30: 11, 44: 1, 42: 1, 40: 1, 52: 1}\n        ```\n        <br/>\n        "}}
# id: 6
# event: result
# data: 1765444030.795158:{"Markdown":{"body":"\n        ###### Job completed (1/10)\n        * range: 0 - 9999\n        * node: 0c33869970f103f489ef84d3e6e01023e451120cab7f438ddfd8b189\n        * found 1229 primes\n\n        ```python\n        {1: 1, 2: 205, 4: 202, 6: 299, 8: 101, 14: 54, 10: 119, 12: 105, 18: 40, 20: 15, 22: 16, 34: 2, 24: 15, 16: 33, 26: 3, 28: 5, 30: 11, 32: 1, 36: 1}\n        ```\n        <br/>\n        "}}
# id: 7
# event: debug
# data: 1765444030.7953:1/10 Jobs completed (10.0%)
# id: 8
# event: debug
# data: 1765444030.800732:2/10 Jobs completed (20.0%)
# id: 9
# event: result
# data: 1765444030.800905:{"Markdown":{"body":"\n        ###### Job completed (3/10)\n        * range: 40000 - 49999\n        * node: 0c33869970f103f489ef84d3e6e01023e451120cab7f438ddfd8b189\n        * found 930 primes\n\n        ```python\n        {4: 112, 18: 52, 6: 180, 2: 114, 24: 27, 12: 108, 22: 18, 10: 92, 8: 72, 20: 19, 54: 2, 26: 8, 36: 7, 16: 32, 30: 13, 14: 48, 32: 6, 34: 3, 60: 1, 52: 2, 28: 7, 58: 1, 40: 2, 42: 1, 38: 2, 50: 1}\n        ```\n        <br/>\n        "}}
# id: 10
# event: debug
# data: 1765444030.8009531:3/10 Jobs completed (30.0%)
# id: 11
# event: result
# data: 1765444030.801145:{"Markdown":{"body":"\n        ###### Job completed (4/10)\n        * range: 20000 - 29999\n        * node: 0c33869970f103f489ef84d3e6e01023e451120cab7f438ddfd8b189\n        * found 983 primes\n\n        ```python\n        {10: 84, 2: 125, 6: 201, 18: 67, 4: 124, 12: 113, 8: 78, 14: 50, 16: 39, 26: 6, 20: 23, 34: 3, 24: 11, 30: 16, 22: 20, 40: 3, 28: 9, 36: 7, 52: 1, 32: 2, 48: 1}\n        ```\n        <br/>\n        "}}
# id: 12
# event: debug
# data: 1765444030.8012102:4/10 Jobs completed (40.0%)
# id: 13
# event: result
# data: 1765444030.8014238:{"Markdown":{"body":"\n        ###### Job completed (5/10)\n        * range: 30000 - 39999\n        * node: 0c33869970f103f489ef84d3e6e01023e451120cab7f438ddfd8b189\n        * found 958 primes\n\n        ```python\n        {2: 124, 16: 35, 18: 58, 12: 99, 6: 192, 4: 113, 14: 39, 22: 27, 8: 81, 10: 102, 20: 24, 24: 11, 38: 3, 30: 15, 26: 11, 72: 1, 50: 1, 36: 1, 34: 3, 28: 6, 40: 2, 32: 2, 62: 1, 42: 3, 54: 1, 52: 1, 44: 2}\n        ```\n        <br/>\n        "}}
# id: 14
# event: debug
# data: 1765444030.8014731:5/10 Jobs completed (50.0%)
# id: 15
# event: result
# data: 1765444030.80222:{"Markdown":{"body":"\n        ###### Job completed (6/10)\n        * range: 60000 - 69999\n        * node: 0c33869970f103f489ef84d3e6e01023e451120cab7f438ddfd8b189\n        * found 878 primes\n\n        ```python\n        {4: 98, 12: 77, 8: 74, 36: 8, 6: 166, 2: 94, 10: 89, 20: 25, 40: 7, 28: 14, 18: 56, 24: 15, 14: 57, 16: 33, 50: 2, 38: 3, 34: 3, 22: 22, 42: 2, 32: 6, 30: 21, 26: 6}\n        ```\n        <br/>\n        "}}
# id: 16
# event: debug
# data: 1765444030.80231:6/10 Jobs completed (60.0%)
# id: 17
# event: result
# data: 1765444030.80527:{"Markdown":{"body":"\n        ###### Job completed (7/10)\n        * range: 70000 - 79999\n        * node: 0c33869970f103f489ef84d3e6e01023e451120cab7f438ddfd8b189\n        * found 902 primes\n\n        ```python\n        {2: 102, 6: 178, 10: 79, 20: 34, 12: 106, 4: 108, 16: 36, 14: 38, 8: 67, 22: 21, 18: 45, 24: 31, 30: 16, 36: 6, 38: 5, 40: 2, 48: 1, 34: 4, 32: 2, 26: 9, 28: 6, 52: 1, 42: 3, 44: 1, 58: 1}\n        ```\n        <br/>\n        "}}
# id: 18
# event: debug
# data: 1765444030.805324:7/10 Jobs completed (70.0%)
# id: 19
# event: result
# data: 1765444030.806018:{"Markdown":{"body":"\n        ###### Job completed (8/10)\n        * range: 50000 - 59999\n        * node: 0c33869970f103f489ef84d3e6e01023e451120cab7f438ddfd8b189\n        * found 924 primes\n\n        ```python\n        {2: 106, 10: 86, 14: 51, 4: 115, 16: 33, 8: 82, 6: 176, 18: 61, 30: 16, 20: 23, 24: 21, 36: 2, 12: 81, 28: 13, 32: 4, 22: 31, 38: 3, 40: 1, 42: 2, 26: 13, 34: 2, 58: 1, 52: 1}\n        ```\n        <br/>\n        "}}
# id: 20
# event: debug
# data: 1765444030.806217:8/10 Jobs completed (80.0%)
# id: 21
# event: result
# data: 1765444030.8239832:{"Markdown":{"body":"\n        ###### Job completed (9/10)\n        * range: 80000 - 89999\n        * node: 0c33869970f103f489ef84d3e6e01023e451120cab7f438ddfd8b189\n        * found 876 primes\n\n        ```python\n        {18: 43, 12: 92, 20: 24, 6: 161, 30: 12, 4: 99, 2: 109, 14: 54, 16: 31, 10: 84, 8: 62, 22: 23, 32: 4, 24: 23, 34: 5, 26: 11, 42: 5, 28: 14, 46: 1, 56: 1, 36: 6, 40: 7, 38: 1, 58: 1, 48: 1, 54: 1, 64: 1}\n        ```\n        <br/>\n        "}}
# id: 22
# event: debug
# data: 1765444030.824107:9/10 Jobs completed (90.0%)
# id: 23
# event: result
# data: 1765444030.826306:{"Markdown":{"body":"\n        ###### Job completed (10/10)\n        * range: 90000 - 100000\n        * node: 0c33869970f103f489ef84d3e6e01023e451120cab7f438ddfd8b189\n        * found 879 primes\n\n        ```python\n        {6: 161, 4: 103, 2: 108, 8: 71, 22: 23, 16: 31, 18: 48, 14: 40, 10: 89, 12: 74, 24: 33, 40: 3, 30: 15, 36: 12, 38: 2, 46: 3, 20: 26, 34: 3, 26: 14, 28: 12, 44: 1, 32: 4, 50: 1, 42: 2}\n        ```\n        <br/>\n        "}}
# id: 24
# event: debug
# data: 1765444030.826448:10/10 Jobs completed (100.0%)
# id: 25
# event: final
# data: 1765444030.82675:{"dict":{"1":1,"2":1224,"4":1215,"6":1940,"8":773,"14":484,"10":916,"12":964,"18":514,"20":238,"22":223,"34":33,"24":206,"16":339,"26":88,"28":98,"30":146,"32":32,"36":54,"44":5,"42":19,"40":28,"52":7,"54":4,"60":1,"58":4,"38":19,"50":5,"48":3,"72":1,"62":1,"46":4,"56":1,"64":1}}
# id: 26
# event: status
# data: 1765444030.896121:finished
# id: 0
# event: alive
# data: 1765444033.993161:service alive
# id: 0
# event: alive
# data: 1765444036.993171:service alive
# id: 0
# event: alive
# data: 1765444039.993189:service alive
# id: 0
# event: eof
# data: end of stream

# %% [markdown]
# ## Payment Integration Demo (text inputs)
#
# Update the `text-inputs` flow with an `agentIdentifier` to enable Masumi payment processing.

# %%
# Update form-example with agentIdentifier for text-inputs
resp = client.post("/expose/", json={
    "name": "form-example",
    "display": "Form Elements Demo",
    "network": "Preprod",
    "bootstrap": "import_path: tests.form_elements_demo:fast_app",
    "meta": [{
        "url": "/form-example/text-inputs",
        "data": """display: Text Input Types Demo
description: Showcases text input components with payment
agentIdentifier: 7e8bdaf2b2b919a3a4b94002cafb50086c0c845fe535d07a77ab7f77ee8e013e3f92bbd2aa41065577ac087a0d55ff96430087324c023b021267ca37
tags:
  - demo
  - forms
  - payment
"""
    }]
})
print(f"form-example update: {resp.status_code}")
pprint(resp.json())
# Out:
# form-example update: 201
# {'bootstrap': 'import_path: tests.form_elements_demo:fast_app',
#  'created': '2025-12-11T09:34:49.992096',
#  'display': 'Form Elements Demo',
#  'enabled': True,
#  'etag': '1765444063.5648289',
#  'flow_stats': '0/0',
#  'heartbeat': 1765444063.52565,
#  'meta': [{'data': 'display: Text Input Types Demo\n'
#                    'description: Showcases text input components with payment\n'
#                    'agentIdentifier: '
#                    '7e8bdaf2b2b919a3a4b94002cafb50086c0c845fe535d07a77ab7f77ee8e013e3f92bbd2aa41065577ac087a0d55ff96430087324c023b021267ca37\n'
#                    'tags:\n'
#                    '  - demo\n'
#                    '  - forms\n'
#                    '  - payment\n',
#            'enabled': True,
#            'heartbeat': None,
#            'state': None,
#            'url': '/form-example/text-inputs'}],
#  'name': 'form-example',
#  'needs_reboot': False,
#  'network': 'Preprod',
#  'stale': False,
#  'state': 'RUNNING',
#  'updated': '2025-12-11T10:07:43.564829'}

# %%
# Refresh form-example to pick up changes
with client.stream("POST", "/boot/refresh/form-example") as resp:
    print(f"Refresh status: {resp.status_code}")
    for line in resp.iter_lines():
        if line:
            print(line)
# Out:
# Refresh status: 200
# ℹ Refreshing expose 'form-example' at 2025-12-11 10:07:48
# ▶ [UPDATE] Step 1/4: Disabling expose 'form-example'
#   [form-example] Expose disabled → enabled=False
# ▶ [DEPLOY] Step 2/4: Running boot process (remove flows)
# ℹ [Boot 1/2] Boot started at 2025-12-11 10:07:48
# ▶ [DEPLOY] [Boot 1/2] Starting Ray Serve deployment
#   • [serve_config.yaml] [Boot 1/2] Loading global configuration → OK
#   • [jkx] [Boot 1/2] Prepared deployment config → route=/jkx
#   • [prime] [Boot 1/2] Prepared deployment config → route=/prime
#   • [sumi-test] [Boot 1/2] Prepared deployment config → route=/sumi-test
#   • [/var/folders/n9/f3p_gzsj7vjfgfw70yqksywcn5rfs9/T/serve_deploy_nh1j37f2.yaml] [Boot 1/2] Created merged deployment config
#   • [serve] [Boot 1/2] Running serve deploy (3 applications)
#   [Boot 1/2] serve deploy command → success
# ✓ [Boot 1/2] Deployment initiated (3 applications)
# ▶ [HEALTH] [Boot 1/2] Waiting for deployments to complete (timeout: 1800s)
#   [jkx] [Boot 1/2] Reached final state → RUNNING
#   [prime] [Boot 1/2] Reached final state → RUNNING
#   [sumi-test] [Boot 1/2] Reached final state → RUNNING
# ✓ [Boot 1/2] All deployments complete (3 running, 0 failed)
# ▶ [REGISTER] [Boot 1/2] Registering flow endpoints
#   • [Boot 1/2] POST http://localhost:3370/flow/register → http://localhost:8005/-/routes
#   [Boot 1/2] Registered 4 flow(s) via /-/routes → None
#   • [jkx] [Boot 1/2] Discovered 1 flow endpoint(s) → serve
#   • [prime] [Boot 1/2] Discovered 2 flow endpoint(s) → , async
#   • [sumi-test] [Boot 1/2] Discovered 1 flow endpoint(s)
# ✓ [Boot 1/2] Flow registration complete (4 registered, 4 discovered)
# ▶ [RETRIEVE] [Boot 1/2] Testing flow endpoints
#   • [jkx] [Boot 1/2] Checking 1 endpoint(s)
#   • [prime] [Boot 1/2] Checking 2 endpoint(s)
#   • [sumi-test] [Boot 1/2] Checking 1 endpoint(s)
#   [jkx] [Boot 1/2] HEAD /jkx/serve → 200 OK (alive)
#   [prime] [Boot 1/2] HEAD /prime/ → 200 OK (alive)
#   [prime] [Boot 1/2] HEAD /prime/async → 200 OK (alive)
#   [sumi-test] [Boot 1/2] HEAD /sumi-test/ → 200 OK (alive)
# ✓ [Boot 1/2] Retrieved 4 flow endpoints (4 alive, 0 dead)
# ▶ [UPDATE] [Boot 1/2] Updating expose metadata
#   • [GET /flow] [Boot 1/2] Fetching registered flows
#   [Boot 1/2] Retrieved flows → 4 flows
#   • [sumi-test] [Boot 1/2] Processing 1 flow(s)
#   [sumi-test] [Boot 1/2] Updated meta → 0 new, 1 preserved
#   • [prime] [Boot 1/2] Processing 2 flow(s)
#   [prime] [Boot 1/2] Updated meta → 0 new, 2 preserved
#   • [jkx] [Boot 1/2] Processing 1 flow(s)
#   [jkx] [Boot 1/2] Updated meta → 0 new, 1 preserved
# ✓ [Boot 1/2] Metadata update complete (0 new, 4 preserved, 4 alive)
# ✔ [Boot 1/2] Boot completed at 2025-12-11 10:07:50 (runtime: 2.3s)
# ▶ [UPDATE] Step 3/4: Enabling expose 'form-example'
#   [form-example] Expose enabled → enabled=True
# ▶ [DEPLOY] Step 4/4: Running boot process (re-add flows)
# ℹ [Boot 2/2] Boot started at 2025-12-11 10:07:50
# ▶ [DEPLOY] [Boot 2/2] Starting Ray Serve deployment
#   • [serve_config.yaml] [Boot 2/2] Loading global configuration → OK
#   • [form-example] [Boot 2/2] Prepared deployment config → route=/form-example
#   • [jkx] [Boot 2/2] Prepared deployment config → route=/jkx
#   • [prime] [Boot 2/2] Prepared deployment config → route=/prime
#   • [sumi-test] [Boot 2/2] Prepared deployment config → route=/sumi-test
#   • [/var/folders/n9/f3p_gzsj7vjfgfw70yqksywcn5rfs9/T/serve_deploy_wninf4k_.yaml] [Boot 2/2] Created merged deployment config
#   • [serve] [Boot 2/2] Running serve deploy (4 applications)
#   [Boot 2/2] serve deploy command → success
# ✓ [Boot 2/2] Deployment initiated (4 applications)
# ▶ [HEALTH] [Boot 2/2] Waiting for deployments to complete (timeout: 1800s)
#   • [form-example] [Boot 2/2] Status: DEPLOYING
#   [jkx] [Boot 2/2] Reached final state → RUNNING
#   [prime] [Boot 2/2] Reached final state → RUNNING
#   [sumi-test] [Boot 2/2] Reached final state → RUNNING
#   [form-example] [Boot 2/2] Reached final state → RUNNING
# ✓ [Boot 2/2] All deployments complete (4 running, 0 failed)
# ▶ [REGISTER] [Boot 2/2] Registering flow endpoints
#   • [Boot 2/2] POST http://localhost:3370/flow/register → http://localhost:8005/-/routes
#   [Boot 2/2] Registered 10 flow(s) via /-/routes → None
#   • [jkx] [Boot 2/2] Discovered 1 flow endpoint(s) → serve
#   • [prime] [Boot 2/2] Discovered 2 flow endpoint(s) → , async
#   • [sumi-test] [Boot 2/2] Discovered 1 flow endpoint(s)
#   • [form-example] [Boot 2/2] Discovered 6 flow endpoint(s) → text-inputs, numeric-inputs, datetime-inputs, selection-inputs, special-inputs, complete-form
# ✓ [Boot 2/2] Flow registration complete (10 registered, 10 discovered)
# ▶ [RETRIEVE] [Boot 2/2] Testing flow endpoints
#   • [jkx] [Boot 2/2] Checking 1 endpoint(s)
#   • [prime] [Boot 2/2] Checking 2 endpoint(s)
#   • [sumi-test] [Boot 2/2] Checking 1 endpoint(s)
#   • [form-example] [Boot 2/2] Checking 6 endpoint(s)
#   [jkx] [Boot 2/2] HEAD /jkx/serve → 200 OK (alive)
#   [prime] [Boot 2/2] HEAD /prime/ → 200 OK (alive)
#   [prime] [Boot 2/2] HEAD /prime/async → 200 OK (alive)
#   [sumi-test] [Boot 2/2] HEAD /sumi-test/ → 200 OK (alive)
#   [form-example] [Boot 2/2] HEAD /form-example/text-inputs → 200 OK (alive)
#   [form-example] [Boot 2/2] HEAD /form-example/numeric-inputs → 200 OK (alive)
#   [form-example] [Boot 2/2] HEAD /form-example/datetime-inputs → 200 OK (alive)
#   [form-example] [Boot 2/2] HEAD /form-example/selection-inputs → 200 OK (alive)
#   [form-example] [Boot 2/2] HEAD /form-example/special-inputs → 200 OK (alive)
#   [form-example] [Boot 2/2] HEAD /form-example/complete-form → 200 OK (alive)
# ✓ [Boot 2/2] Retrieved 10 flow endpoints (10 alive, 0 dead)
# ▶ [UPDATE] [Boot 2/2] Updating expose metadata
#   • [GET /flow] [Boot 2/2] Fetching registered flows
#   [Boot 2/2] Retrieved flows → 10 flows
#   • [form-example] [Boot 2/2] Processing 6 flow(s)
#   [form-example] [Boot 2/2] Updated meta → 5 new, 1 preserved
#   • [sumi-test] [Boot 2/2] Processing 1 flow(s)
#   [sumi-test] [Boot 2/2] Updated meta → 0 new, 1 preserved
#   • [prime] [Boot 2/2] Processing 2 flow(s)
#   [prime] [Boot 2/2] Updated meta → 0 new, 2 preserved
#   • [jkx] [Boot 2/2] Processing 1 flow(s)
#   [jkx] [Boot 2/2] Updated meta → 0 new, 1 preserved
# ✓ [Boot 2/2] Metadata update complete (5 new, 5 preserved, 10 alive)
# ✔ [Boot 2/2] Boot completed at 2025-12-11 10:07:56 (runtime: 6.6s)
# ✔ Refresh complete at 2025-12-11 10:07:56 (runtime: 8.9s)

# %% [markdown]
# ### check availability

# %%
# Start a job on text-inputs (now with payment processing)
resp = client.get("/sumi/form-example/text-inputs/availability")
print(f"Status: {resp.status_code}")
result = resp.json()
pprint(result)
# Out:
# Status: 200
# {'message': 'Text Input Types Demo is ready to accept jobs',
#  'status': 'available',
#  'type': 'masumi-agent'}

# %%
import secrets

identifier = secrets.token_hex(13)

# %%
# Start a job on text-inputs (now with payment processing)
resp = client.post("/sumi/form-example/text-inputs/start_job", json={
    "identifier_from_purchaser": identifier,
    "input_data": {
        "email": "user@example.com",
        "username": "PaymentUser",
        "password": "secretpass123"
    }
})

print(f"Status: {resp.status_code}")
result = resp.json()
pprint(result)

payment_job_id = result.get("job_id")
print(f"\nJob ID: {payment_job_id}")
# Out:
# Status: 201
# {'error': None,
#  'identifier_from_purchaser': 'ac782a97953ce4bfcfa25e6fff',
#  'input_schema': None,
#  'job_id': '693a8a066dd65932eccf9bfb',
#  'result': None,
#  'runtime': None,
#  'started_at': 68691.545,
#  'status': 'running',
#  'updated_at': 68691.709}
#
# Job ID: 693a8a066dd65932eccf9bfb

# %%
# Poll until job requires payment or completes
awaiting_payment_count = 0
for i in range(60):
    resp = client.get(f"/sumi/status/{payment_job_id}")
    status_data = resp.json()
    job_status = status_data.get("status")

    print(f"[{i+1}/60] Status: {job_status}")

    if job_status == "awaiting_payment":
        awaiting_payment_count += 1
        if awaiting_payment_count >= 3:
            print("\nJob awaiting payment - need to submit payment")
            pprint(status_data)
            break

    if job_status in ("completed", "failed"):
        print("\nFinal result:")
        pprint(status_data)
        break

    time.sleep(1)
else:
    print("Job did not complete within timeout")
# Out:
# [1/60] Status: running
# [2/60] Status: awaiting_payment
# [3/60] Status: awaiting_payment
# [4/60] Status: awaiting_payment
#
# Job awaiting payment - need to submit payment
# {'error': None,
#  'identifier_from_purchaser': 'ac782a97953ce4bfcfa25e6fff',
#  'input_schema': None,
#  'job_id': '693a8a066dd65932eccf9bfb',
#  'result': None,
#  'runtime': 2.0530340671539307,
#  'started_at': 1765444104.275226,
#  'status': 'awaiting_payment',
#  'updated_at': 1765444106.3282602}

# %% [markdown]
# ### Simulate Payment (Masumi Purchase API)
#
# Extract payment information from the `kind='payment'` event and simulate a purchase.

# %%
# Extract payment information from the event stream
import json

payment_info = None
with client.stream("GET", f"/outputs/stream/{payment_job_id}") as resp:
    for line in resp.iter_lines():
        if line and line.startswith("event: payment"):
            # Next line is the data
            continue
        if line and line.startswith("data:") and payment_info is None:
            # Check if this is payment data
            data_part = line[5:].strip()  # Remove "data:" prefix
            if ":" in data_part:
                ts, json_str = data_part.split(":", 1)
                try:
                    parsed = json.loads(json_str)
                    if "dict" in parsed and "blockchainIdentifier" in parsed["dict"]:
                        payment_info = parsed["dict"]
                        print("Found payment event:")
                        pprint(payment_info)
                        break
                except:
                    pass

if not payment_info:
    print("No payment event found - job may not have payment configured")
# Out:
# Found payment event:
# {'agentIdentifier': '7e8bdaf2b2b919a3a4b94002cafb50086c0c845fe535d07a77ab7f77ee8e013e3f92bbd2aa41065577ac087a0d55ff96430087324c023b021267ca37',
#  'blockchainIdentifier': '...',
#  'externalDisputeUnlockTime': '1765489105000',
#  'inputHash': '7c9ab94cd55e9c49dcbf65122f7446df2464d3945778624b1f67313f6aa749ec',
#  'network': 'Preprod',
#  'payByTime': '1765445305000',
#  'step': 'initialized',
#  'submitResultTime': '1765445905000',
#  'unlockTime': '1765467505000'}

# %%
# Extract variables for purchase request
if payment_info:
    aid = payment_info.get("agentIdentifier")
    bid = payment_info.get("blockchainIdentifier")
    ih = payment_info.get("inputHash")
    pbt = payment_info.get("payByTime")
    srt = payment_info.get("submitResultTime")
    ult = payment_info.get("unlockTime")
    edut = payment_info.get("externalDisputeUnlockTime")
    
    print("Payment variables extracted:")
    print(f"  agentIdentifier: {aid}")
    print(f"  blockchainIdentifier: {bid}")
    print(f"  inputHash: {ih}")
    print(f"  payByTime: {pbt}")
    print(f"  submitResultTime: {srt}")
    print(f"  unlockTime: {ult}")
    print(f"  externalDisputeUnlockTime: {edut}")
# Out:
# Payment variables extracted:
#   agentIdentifier: 7e8bdaf2b2b919a3a4b94002cafb50086c0c845fe535d07a77ab7f77ee8e013e3f92bbd2aa41065577ac087a0d55ff96430087324c023b021267ca37
#   blockchainIdentifier: ...
#   inputHash: 7c9ab94cd55e9c49dcbf65122f7446df2464d3945778624b1f67313f6aa749ec
#   payByTime: 1765445305000
#   submitResultTime: 1765445905000
#   unlockTime: 1765467505000
#   externalDisputeUnlockTime: 1765489105000

# %%
# Simulate payment via Masumi Purchase API
purchase = httpx.post(
    "https://payment.masumi.network/api/v1/purchase/",
    headers={
        "accept": "application/json",
        "token": "iofsnaiojdoiewqajdriknjonasfoinasd",
        "Content-Type": "application/json"
    },
    json={
        "identifierFromPurchaser": identifier,
        "network": "Preprod",
        "sellerVkey": "2a581594ee277e1625a4e999b1b2d788f54217c35bd7f50ea9aecd64",
        "blockchainIdentifier": bid,
        "payByTime": pbt,
        "submitResultTime": srt,
        "unlockTime": ult,
        "externalDisputeUnlockTime": edut,
        "agentIdentifier": aid,
        "inputHash": ih
    },
    timeout=30.0
)
print(f"Purchase status: {purchase.status_code}")
pprint(purchase.json())
# Out:
# Purchase status: 200
# {'data': {'CurrentTransaction': None,
#           'NextAction': {'errorNote': None,
#                          'errorType': None,
#                          'requestedAction': 'FundsLockingRequested'},
#           'PaidFunds': [{'amount': '10000000', 'unit': ''}],
#           'PaymentSource': {'id': 'cmfx3ni6j000nvbfuhrnx0ehb',
#                             'network': 'Preprod',
#                             'policyId': '7e8bdaf2b2b919a3a4b94002cafb50086c0c845fe535d07a77ab7f77',
#                             'smartContractAddress': 'addr_test1wz7j4kmg2cs7yf92uat3ed4a3u97kr7axxr4avaz0lhwdsqukgwfm'},
#           'SellerWallet': {'id': 'cmh3cymtx00gets0eta1htlxu',
#                            'walletVkey': '2a581594ee277e1625a4e999b1b2d788f54217c35bd7f50ea9aecd64'},
#           'SmartContractWallet': None,
#           'WithdrawnForBuyer': [],
#           'WithdrawnForSeller': [],
#           'blockchainIdentifier': '...',
#           'createdAt': '2025-12-11T09:08:37.717Z',
#           'externalDisputeUnlockTime': '1765489105000',
#           'id': 'cmj17ufh101ces20ez2mr806o',
#           'inputHash': '7c9ab94cd55e9c49dcbf65122f7446df2464d3945778624b1f67313f6aa749ec',
#           'lastCheckedAt': None,
#           'metadata': None,
#           'onChainState': None,
#           'payByTime': '1765445305000',
#           'requestedById': 'cmfx3nhp60000vbfu8zpn0agd',
#           'resultHash': '',
#           'submitResultTime': '1765445905000',
#           'unlockTime': '1765467505000',
#           'updatedAt': '2025-12-11T09:08:37.717Z'},
#  'status': 'success'}

# %%
# Poll for job status after payment
for i in range(360):
    resp = client.get(f"/sumi/status/{payment_job_id}")
    status_data = resp.json()
    job_status = status_data.get("status")

    print(f"[{i+1}/360] Status: {job_status}")

    if job_status in ("completed", "failed"):
        print("\nFinal result:")
        pprint(status_data)
        break

    time.sleep(1)
else:
    print("\nCurrent status:")
    pprint(status_data)
# Out:
# [1/360] Status: awaiting_payment
# [2/360] Status: awaiting_payment
# [3/360] Status: awaiting_payment
# [4/360] Status: awaiting_payment
# [5/360] Status: awaiting_payment
# [6/360] Status: awaiting_payment
# [7/360] Status: awaiting_payment
# [8/360] Status: awaiting_payment
# [9/360] Status: awaiting_payment
# [10/360] Status: awaiting_payment
# [11/360] Status: awaiting_payment
# [12/360] Status: awaiting_payment
# [13/360] Status: awaiting_payment
# [14/360] Status: awaiting_payment
# [15/360] Status: awaiting_payment
# [16/360] Status: awaiting_payment
# [17/360] Status: awaiting_payment
# [18/360] Status: awaiting_payment
# [19/360] Status: awaiting_payment
# [20/360] Status: awaiting_payment
# [21/360] Status: awaiting_payment
# [22/360] Status: awaiting_payment
# [23/360] Status: awaiting_payment
# [24/360] Status: awaiting_payment
# [25/360] Status: awaiting_payment
# [26/360] Status: awaiting_payment
# [27/360] Status: awaiting_payment
# [28/360] Status: awaiting_payment
# [29/360] Status: awaiting_payment
# [30/360] Status: awaiting_payment
# [31/360] Status: awaiting_payment
# [32/360] Status: awaiting_payment
# [33/360] Status: awaiting_payment
# [34/360] Status: awaiting_payment
# [35/360] Status: awaiting_payment
# [36/360] Status: awaiting_payment
# [37/360] Status: awaiting_payment
# [38/360] Status: awaiting_payment
# [39/360] Status: awaiting_payment
# [40/360] Status: awaiting_payment
# [41/360] Status: awaiting_payment
# [42/360] Status: awaiting_payment
# [43/360] Status: awaiting_payment
# [44/360] Status: awaiting_payment
# [45/360] Status: awaiting_payment
# [46/360] Status: awaiting_payment
# [47/360] Status: awaiting_payment
# [48/360] Status: awaiting_payment
# [49/360] Status: awaiting_payment
# [50/360] Status: awaiting_payment
# [51/360] Status: awaiting_payment
# [52/360] Status: awaiting_payment
# [53/360] Status: awaiting_payment
# [54/360] Status: awaiting_payment
# [55/360] Status: awaiting_payment
# [56/360] Status: awaiting_payment
# [57/360] Status: awaiting_payment
# [58/360] Status: awaiting_payment
# [59/360] Status: awaiting_payment
# [60/360] Status: awaiting_payment
# [61/360] Status: awaiting_payment
# [62/360] Status: awaiting_payment
# [63/360] Status: awaiting_payment
# [64/360] Status: awaiting_payment
# [65/360] Status: awaiting_payment
# [66/360] Status: awaiting_payment
# [67/360] Status: awaiting_payment
# [68/360] Status: awaiting_payment
# [69/360] Status: awaiting_payment
# [70/360] Status: awaiting_payment
# [71/360] Status: awaiting_payment
# [72/360] Status: awaiting_payment
# [73/360] Status: awaiting_payment
# [74/360] Status: awaiting_payment
# [75/360] Status: awaiting_payment
# [76/360] Status: awaiting_payment
# [77/360] Status: awaiting_payment
# [78/360] Status: awaiting_payment
# [79/360] Status: awaiting_payment
# [80/360] Status: awaiting_payment
# [81/360] Status: awaiting_payment
# [82/360] Status: awaiting_payment
# [83/360] Status: running
# [84/360] Status: completed
#
# Final result:
# {'error': None,
#  'identifier_from_purchaser': 'ac782a97953ce4bfcfa25e6fff',
#  'input_schema': None,
#  'job_id': '693a8a066dd65932eccf9bfb',
#  'result': {'dict': {'ok': True}},
#  'runtime': 160.7451877593994,
#  'started_at': 1765444104.275226,
#  'status': 'completed',
#  'updated_at': 1765444265.0204139}

# %% [markdown]
# ## HITL/Lock Payment Integration Demo (Two-Step Masumi Test Flow)
#
# This demo showcases the two-step Masumi test flow with:
# 1. Initial form submission (Name + Date validation)
# 2. Payment initialization and wait for `FundsLocked`
# 3. Lock/HITL step (greeting form) - `awaiting_input` status
# 4. Provide input to release lock
# 5. Job completion and payment finalization
#
# The flow uses `tests.test_masumi:fast_app` which implements:
# - Date validation (must be in future)
# - Lock callback for human greeting input
# - Lease callback to process the greeting
# - Markdown result generation

# %%
# Update sumi-test with agentIdentifier for payment integration
resp = client.post("/expose/", json={
    "name": "sumi-test",
    "display": "Masumi Two-Stage Service",
    "network": "Preprod",
    "bootstrap": "import_path: tests.test_masumi:fast_app",
    "meta": [{
        "url": "/sumi-test/",
        "data": """display: Two-Stage HITL Demo
description: Two-stage service with payment, date validation, and HITL lock
agentIdentifier: 7e8bdaf2b2b919a3a4b94002cafb50086c0c845fe535d07a77ab7f77ee8e013e3f92bbd2aa41065577ac087a0d55ff96430087324c023b021267ca37
tags:
  - masumi
  - hitl
  - payment
  - two-stage
"""
    }]
})
print(f"sumi-test update: {resp.status_code}")
pprint(resp.json())
# Out:
# sumi-test update: 201
# {'bootstrap': 'import_path: tests.test_masumi:fast_app',
#  'created': '2025-12-11T10:04:43.727819',
#  'display': 'Masumi Two-Stage Service',
#  'enabled': True,
#  'etag': '1765446109.909014',
#  'flow_stats': '0/0',
#  'heartbeat': 1765446109.855795,
#  'meta': [{'data': 'display: Two-Stage HITL Demo\n'
#                    'description: Two-stage service with payment, date '
#                    'validation, and HITL lock\n'
#                    'agentIdentifier: '
#                    '7e8bdaf2b2b919a3a4b94002cafb50086c0c845fe535d07a77ab7f77ee8e013e3f92bbd2aa41065577ac087a0d55ff96430087324c023b021267ca37\n'
#                    'tags:\n'
#                    '  - masumi\n'
#                    '  - hitl\n'
#                    '  - payment\n'
#                    '  - two-stage\n',
#            'enabled': True,
#            'heartbeat': None,
#            'state': None,
#            'url': '/sumi-test/'}],
#  'name': 'sumi-test',
#  'needs_reboot': False,
#  'network': 'Preprod',
#  'stale': False,
#  'state': 'RUNNING',
#  'updated': '2025-12-11T10:41:49.909014'}

# %%
# Refresh sumi-test to pick up changes
with client.stream("POST", "/boot/refresh/sumi-test") as resp:
    print(f"Refresh status: {resp.status_code}")
    for line in resp.iter_lines():
        if line:
            print(line)
# Out:
# Refresh status: 200
# ℹ Refreshing expose 'sumi-test' at 2025-12-11 10:41:50
# ▶ [UPDATE] Step 1/4: Disabling expose 'sumi-test'
#   [sumi-test] Expose disabled → enabled=False
# ▶ [DEPLOY] Step 2/4: Running boot process (remove flows)
# ℹ [Boot 1/2] Boot started at 2025-12-11 10:41:50
# ▶ [DEPLOY] [Boot 1/2] Starting Ray Serve deployment
#   • [serve_config.yaml] [Boot 1/2] Loading global configuration → OK
#   • [form-example] [Boot 1/2] Prepared deployment config → route=/form-example
#   • [jkx] [Boot 1/2] Prepared deployment config → route=/jkx
#   • [prime] [Boot 1/2] Prepared deployment config → route=/prime
#   • [/var/folders/n9/f3p_gzsj7vjfgfw70yqksywcn5rfs9/T/serve_deploy_4iuc9_30.yaml] [Boot 1/2] Created merged deployment config
#   • [serve] [Boot 1/2] Running serve deploy (3 applications)
#   [Boot 1/2] serve deploy command → success
# ✓ [Boot 1/2] Deployment initiated (3 applications)
# ▶ [HEALTH] [Boot 1/2] Waiting for deployments to complete (timeout: 1800s)
#   [form-example] [Boot 1/2] Reached final state → RUNNING
#   [jkx] [Boot 1/2] Reached final state → RUNNING
#   [prime] [Boot 1/2] Reached final state → RUNNING
# ✓ [Boot 1/2] All deployments complete (3 running, 0 failed)
# ▶ [REGISTER] [Boot 1/2] Registering flow endpoints
#   • [Boot 1/2] POST http://localhost:3370/flow/register → http://localhost:8005/-/routes
#   [Boot 1/2] Registered 9 flow(s) via /-/routes → None
#   • [form-example] [Boot 1/2] Discovered 6 flow endpoint(s) → text-inputs, numeric-inputs, datetime-inputs, selection-inputs, special-inputs, complete-form
#   • [jkx] [Boot 1/2] Discovered 1 flow endpoint(s) → serve
#   • [prime] [Boot 1/2] Discovered 2 flow endpoint(s) → , async
# ✓ [Boot 1/2] Flow registration complete (9 registered, 9 discovered)
# ▶ [RETRIEVE] [Boot 1/2] Testing flow endpoints
#   • [form-example] [Boot 1/2] Checking 6 endpoint(s)
#   • [jkx] [Boot 1/2] Checking 1 endpoint(s)
#   • [prime] [Boot 1/2] Checking 2 endpoint(s)
#   [form-example] [Boot 1/2] HEAD /form-example/text-inputs → 200 OK (alive)
#   [form-example] [Boot 1/2] HEAD /form-example/numeric-inputs → 200 OK (alive)
#   [form-example] [Boot 1/2] HEAD /form-example/datetime-inputs → 200 OK (alive)
#   [form-example] [Boot 1/2] HEAD /form-example/selection-inputs → 200 OK (alive)
#   [form-example] [Boot 1/2] HEAD /form-example/special-inputs → 200 OK (alive)
#   [form-example] [Boot 1/2] HEAD /form-example/complete-form → 200 OK (alive)
#   [jkx] [Boot 1/2] HEAD /jkx/serve → 200 OK (alive)
#   [prime] [Boot 1/2] HEAD /prime/ → 200 OK (alive)
#   [prime] [Boot 1/2] HEAD /prime/async → 200 OK (alive)
# ✓ [Boot 1/2] Retrieved 9 flow endpoints (9 alive, 0 dead)
# ▶ [UPDATE] [Boot 1/2] Updating expose metadata
#   • [GET /flow] [Boot 1/2] Fetching registered flows
#   [Boot 1/2] Retrieved flows → 9 flows
#   • [form-example] [Boot 1/2] Processing 6 flow(s)
#   [form-example] [Boot 1/2] Updated meta → 0 new, 6 preserved
#   • [prime] [Boot 1/2] Processing 2 flow(s)
#   [prime] [Boot 1/2] Updated meta → 0 new, 2 preserved
#   • [jkx] [Boot 1/2] Processing 1 flow(s)
#   [jkx] [Boot 1/2] Updated meta → 0 new, 1 preserved
# ✓ [Boot 1/2] Metadata update complete (0 new, 9 preserved, 9 alive)
# ✔ [Boot 1/2] Boot completed at 2025-12-11 10:41:56 (runtime: 6.1s)
# ▶ [UPDATE] Step 3/4: Enabling expose 'sumi-test'
#   [sumi-test] Expose enabled → enabled=True
# ▶ [DEPLOY] Step 4/4: Running boot process (re-add flows)
# ℹ [Boot 2/2] Boot started at 2025-12-11 10:41:56
# ▶ [DEPLOY] [Boot 2/2] Starting Ray Serve deployment
#   • [serve_config.yaml] [Boot 2/2] Loading global configuration → OK
#   • [form-example] [Boot 2/2] Prepared deployment config → route=/form-example
#   • [jkx] [Boot 2/2] Prepared deployment config → route=/jkx
#   • [prime] [Boot 2/2] Prepared deployment config → route=/prime
#   • [sumi-test] [Boot 2/2] Prepared deployment config → route=/sumi-test
#   • [/var/folders/n9/f3p_gzsj7vjfgfw70yqksywcn5rfs9/T/serve_deploy_zvciptx0.yaml] [Boot 2/2] Created merged deployment config
#   • [serve] [Boot 2/2] Running serve deploy (4 applications)
#   [Boot 2/2] serve deploy command → success
# ✓ [Boot 2/2] Deployment initiated (4 applications)
# ▶ [HEALTH] [Boot 2/2] Waiting for deployments to complete (timeout: 1800s)
#   [form-example] [Boot 2/2] Reached final state → RUNNING
#   [jkx] [Boot 2/2] Reached final state → RUNNING
#   [prime] [Boot 2/2] Reached final state → RUNNING
#   • [sumi-test] [Boot 2/2] Status: DEPLOYING
#   [sumi-test] [Boot 2/2] Reached final state → RUNNING
# ✓ [Boot 2/2] All deployments complete (4 running, 0 failed)
# ▶ [REGISTER] [Boot 2/2] Registering flow endpoints
#   • [Boot 2/2] POST http://localhost:3370/flow/register → http://localhost:8005/-/routes
#   [Boot 2/2] Registered 10 flow(s) via /-/routes → None
#   • [form-example] [Boot 2/2] Discovered 6 flow endpoint(s) → text-inputs, numeric-inputs, datetime-inputs, selection-inputs, special-inputs, complete-form
#   • [jkx] [Boot 2/2] Discovered 1 flow endpoint(s) → serve
#   • [prime] [Boot 2/2] Discovered 2 flow endpoint(s) → , async
#   • [sumi-test] [Boot 2/2] Discovered 1 flow endpoint(s)
# ✓ [Boot 2/2] Flow registration complete (10 registered, 10 discovered)
# ▶ [RETRIEVE] [Boot 2/2] Testing flow endpoints
#   • [form-example] [Boot 2/2] Checking 6 endpoint(s)
#   • [jkx] [Boot 2/2] Checking 1 endpoint(s)
#   • [prime] [Boot 2/2] Checking 2 endpoint(s)
#   • [sumi-test] [Boot 2/2] Checking 1 endpoint(s)
#   [form-example] [Boot 2/2] HEAD /form-example/text-inputs → 200 OK (alive)
#   [form-example] [Boot 2/2] HEAD /form-example/numeric-inputs → 200 OK (alive)
#   [form-example] [Boot 2/2] HEAD /form-example/datetime-inputs → 200 OK (alive)
#   [form-example] [Boot 2/2] HEAD /form-example/selection-inputs → 200 OK (alive)
#   [form-example] [Boot 2/2] HEAD /form-example/special-inputs → 200 OK (alive)
#   [form-example] [Boot 2/2] HEAD /form-example/complete-form → 200 OK (alive)
#   [jkx] [Boot 2/2] HEAD /jkx/serve → 200 OK (alive)
#   [prime] [Boot 2/2] HEAD /prime/ → 200 OK (alive)
#   [prime] [Boot 2/2] HEAD /prime/async → 200 OK (alive)
#   [sumi-test] [Boot 2/2] HEAD /sumi-test/ → 200 OK (alive)
# ✓ [Boot 2/2] Retrieved 10 flow endpoints (10 alive, 0 dead)
# ▶ [UPDATE] [Boot 2/2] Updating expose metadata
#   • [GET /flow] [Boot 2/2] Fetching registered flows
#   [Boot 2/2] Retrieved flows → 10 flows
#   • [form-example] [Boot 2/2] Processing 6 flow(s)
#   [form-example] [Boot 2/2] Updated meta → 0 new, 6 preserved
#   • [sumi-test] [Boot 2/2] Processing 1 flow(s)
#   [sumi-test] [Boot 2/2] Updated meta → 0 new, 1 preserved
#   • [prime] [Boot 2/2] Processing 2 flow(s)
#   [prime] [Boot 2/2] Updated meta → 0 new, 2 preserved
#   • [jkx] [Boot 2/2] Processing 1 flow(s)
#   [jkx] [Boot 2/2] Updated meta → 0 new, 1 preserved
# ✓ [Boot 2/2] Metadata update complete (0 new, 10 preserved, 10 alive)
# ✔ [Boot 2/2] Boot completed at 2025-12-11 10:42:07 (runtime: 10.6s)
# ✔ Refresh complete at 2025-12-11 10:42:07 (runtime: 16.7s)

# %% [markdown]
# ### Check Availability and Input Schema

# %%
# Check availability for sumi-test
resp = client.get("/sumi/sumi-test/availability")
print(f"Status: {resp.status_code}")
pprint(resp.json())
# Out:
# Status: 200
# {'message': 'Two-Stage HITL Demo is ready to accept jobs',
#  'status': 'available',
#  'type': 'masumi-agent'}

# %%
# Get input schema for sumi-test (two-stage flow)
resp = client.get("/sumi/sumi-test/input_schema")
print(f"Status: {resp.status_code}")
schema = resp.json()
pprint(schema)

# Display required fields
if schema.get("input_data"):
    print("\nInput Fields:")
    for field in schema["input_data"]:
        validations = field.get("validations") or {}
        required = "required" if not validations.get("optional") else "optional"
        print(f"  • {field.get('name', field.get('id'))} ({field.get('type')}) - {required}")
# Out:
# Status: 200
# {'input_data': [{'data': {'placeholder': 'Enter your name'},
#                  'id': 'name',
#                  'name': 'Name',
#                  'type': 'text',
#                  'validations': {'optional': True}},
#                 {'data': None,
#                  'id': 'date',
#                  'name': 'Date',
#                  'type': 'date',
#                  'validations': {'min': '2025-12-12'}}],
#  'input_groups': None}
#
# Input Fields:
#   • Name (text) - optional
#   • Date (date) - required

# %% [markdown]
# ### Start Job with Payment (Two-Stage Flow)
#
# Submit a job with valid future date. The flow will:
# 1. Initialize payment with Masumi
# 2. Wait for `FundsLocked` (status: `awaiting_payment`)
# 3. After payment, create a lock for human input (status: `awaiting_input`)

# %%
import secrets
from datetime import date, timedelta

# Generate unique identifier for this job
hitl_identifier = secrets.token_hex(13)
print(f"Identifier: {hitl_identifier}")

# Calculate a future date (7 days from now)
future_date = (date.today() + timedelta(days=7)).isoformat()
print(f"Future date: {future_date}")
# Out:
# Identifier: 3dcc8fa0662cf9bb236dcedb06
# Future date: 2025-12-18

# %%
# Start a job on sumi-test (with payment and HITL lock)
resp = client.post("/sumi/sumi-test/start_job", json={
    "identifier_from_purchaser": hitl_identifier,
    "input_data": {
        "name": "HITL Test User",
        "date": future_date
    }
})

print(f"Status: {resp.status_code}")
result = resp.json()
pprint(result)

hitl_job_id = result.get("job_id")
print(f"\nJob ID: {hitl_job_id}")
# Out:
# Status: 201
# {'error': None,
#  'identifier_from_purchaser': '3dcc8fa0662cf9bb236dcedb06',
#  'input_schema': None,
#  'job_id': '693a91fb6dd65955fe1c6ccd',
#  'result': None,
#  'runtime': None,
#  'started_at': 70728.492,
#  'status': 'running',
#  'updated_at': 70728.721}
#
# Job ID: 693a91fb6dd65955fe1c6ccd

# %%
# Poll until job requires payment
awaiting_payment_count = 0
for i in range(60):
    resp = client.get(f"/sumi/status/{hitl_job_id}")
    status_data = resp.json()
    job_status = status_data.get("status")

    print(f"[{i+1}/60] Status: {job_status}")

    if job_status == "awaiting_payment":
        awaiting_payment_count += 1
        if awaiting_payment_count >= 3:
            print("\nJob awaiting payment - need to submit payment")
            pprint(status_data)
            break

    if job_status in ("awaiting_input", "completed", "failed"):
        print(f"\nJob reached {job_status}:")
        pprint(status_data)
        break

    time.sleep(1)
else:
    print("Timeout waiting for payment status")
# Out:
# [1/60] Status: None
# [2/60] Status: running
# [3/60] Status: running
# [4/60] Status: awaiting_payment
# [5/60] Status: awaiting_payment
# [6/60] Status: awaiting_payment
#
# Job awaiting payment - need to submit payment
# {'error': None,
#  'identifier_from_purchaser': '3dcc8fa0662cf9bb236dcedb06',
#  'input_schema': None,
#  'job_id': '693a91fb6dd65955fe1c6ccd',
#  'result': None,
#  'runtime': 2.703547239303589,
#  'started_at': 1765446140.8103628,
#  'status': 'awaiting_payment',
#  'updated_at': 1765446143.51391}

# %% [markdown]
# ### Simulate Payment (Masumi Purchase API)
#
# Extract payment info and simulate the purchase to lock funds.

# %%
# Extract payment information from the event stream
import json as json_module

hitl_payment_info = None
with client.stream("GET", f"/outputs/stream/{hitl_job_id}") as resp:
    for line in resp.iter_lines():
        if line and line.startswith("data:") and hitl_payment_info is None:
            data_part = line[5:].strip()
            if ":" in data_part:
                ts, json_str = data_part.split(":", 1)
                try:
                    parsed = json_module.loads(json_str)
                    if "dict" in parsed and "blockchainIdentifier" in parsed["dict"]:
                        hitl_payment_info = parsed["dict"]
                        print("Found payment event:")
                        pprint(hitl_payment_info)
                        break
                except:
                    pass

if not hitl_payment_info:
    print("No payment event found - job may not have payment configured")
# Out:
# Found payment event:
# {'agentIdentifier': '7e8bdaf2b2b919a3a4b94002cafb50086c0c845fe535d07a77ab7f77ee8e013e3f92bbd2aa41065577ac087a0d55ff96430087324c023b021267ca37',
#  'blockchainIdentifier': '...',
#  'externalDisputeUnlockTime': '1765491143000',
#  'inputHash': '23f87ba3b375a0a5ecbc2d56ff2da082a3752c8d43cb9552a7495bd43c7f0e12',
#  'network': 'Preprod',
#  'payByTime': '1765447343000',
#  'step': 'initialized',
#  'submitResultTime': '1765447943000',
#  'unlockTime': '1765469543000'}

# %%
# Extract variables for purchase request
if hitl_payment_info:
    hitl_aid = hitl_payment_info.get("agentIdentifier")
    hitl_bid = hitl_payment_info.get("blockchainIdentifier")
    hitl_ih = hitl_payment_info.get("inputHash")
    hitl_pbt = hitl_payment_info.get("payByTime")
    hitl_srt = hitl_payment_info.get("submitResultTime")
    hitl_ult = hitl_payment_info.get("unlockTime")
    hitl_edut = hitl_payment_info.get("externalDisputeUnlockTime")
    
    print("Payment variables extracted:")
    print(f"  agentIdentifier: {hitl_aid}")
    print(f"  blockchainIdentifier: {hitl_bid}")
    print(f"  inputHash: {hitl_ih}")
    print(f"  payByTime: {hitl_pbt}")
    print(f"  submitResultTime: {hitl_srt}")
# Out:
# Payment variables extracted:
#   agentIdentifier: 7e8bdaf2b2b919a3a4b94002cafb50086c0c845fe535d07a77ab7f77ee8e013e3f92bbd2aa41065577ac087a0d55ff96430087324c023b021267ca37
#   blockchainIdentifier: ...
#   inputHash: 23f87ba3b375a0a5ecbc2d56ff2da082a3752c8d43cb9552a7495bd43c7f0e12
#   payByTime: 1765447343000
#   submitResultTime: 1765447943000

# %%
# Simulate payment via Masumi Purchase API
if hitl_payment_info:
    hitl_purchase = httpx.post(
        "https://payment.masumi.network/api/v1/purchase/",
        headers={
            "accept": "application/json",
            "token": "iofsnaiojdoiewqajdriknjonasfoinasd",
            "Content-Type": "application/json"
        },
        json={
            "identifierFromPurchaser": hitl_identifier,
            "network": "Preprod",
            "sellerVkey": "2a581594ee277e1625a4e999b1b2d788f54217c35bd7f50ea9aecd64",
            "blockchainIdentifier": hitl_bid,
            "payByTime": hitl_pbt,
            "submitResultTime": hitl_srt,
            "unlockTime": hitl_ult,
            "externalDisputeUnlockTime": hitl_edut,
            "agentIdentifier": hitl_aid,
            "inputHash": hitl_ih
        },
        timeout=30.0
    )
    print(f"Purchase status: {hitl_purchase.status_code}")
    pprint(hitl_purchase.json())
else:
    print("No payment info available - skipping purchase")
# Out:
# Purchase status: 200
# {'data': {'CurrentTransaction': None,
#           'NextAction': {'errorNote': None,
#                          'errorType': None,
#                          'requestedAction': 'FundsLockingRequested'},
#           'PaidFunds': [{'amount': '10000000', 'unit': ''}],
#           'PaymentSource': {'id': 'cmfx3ni6j000nvbfuhrnx0ehb',
#                             'network': 'Preprod',
#                             'policyId': '7e8bdaf2b2b919a3a4b94002cafb50086c0c845fe535d07a77ab7f77',
#                             'smartContractAddress': 'addr_test1wz7j4kmg2cs7yf92uat3ed4a3u97kr7axxr4avaz0lhwdsqukgwfm'},
#           'SellerWallet': {'id': 'cmh3cymtx00gets0eta1htlxu',
#                            'walletVkey': '2a581594ee277e1625a4e999b1b2d788f54217c35bd7f50ea9aecd64'},
#           'SmartContractWallet': None,
#           'WithdrawnForBuyer': [],
#           'WithdrawnForSeller': [],
#           'blockchainIdentifier': '...',
#           'createdAt': '2025-12-11T09:42:33.141Z',
#           'externalDisputeUnlockTime': '1765491143000',
#           'id': 'cmj19220l01els20en8gtoush',
#           'inputHash': '23f87ba3b375a0a5ecbc2d56ff2da082a3752c8d43cb9552a7495bd43c7f0e12',
#           'lastCheckedAt': None,
#           'metadata': None,
#           'onChainState': None,
#           'payByTime': '1765447343000',
#           'requestedById': 'cmfx3nhp60000vbfu8zpn0agd',
#           'resultHash': '',
#           'submitResultTime': '1765447943000',
#           'unlockTime': '1765469543000',
#           'updatedAt': '2025-12-11T09:42:33.141Z'},
#  'status': 'success'}

# %% [markdown]
# ### Wait for HITL Lock (awaiting_input)
#
# After payment is confirmed, the job will create a lock requiring human input.
# The status will change to `awaiting_input` with `input_schema` containing the lock form.

# %%
# Poll until job reaches awaiting_input status
lock_info = None
for i in range(360):
    resp = client.get(f"/sumi/status/{hitl_job_id}")
    status_data = resp.json()
    job_status = status_data.get("status")

    print(f"[{i+1}/180] Status: {job_status}")

    if job_status == "awaiting_input":
        print("\nJob awaiting human input (HITL lock):")
        pprint(status_data)
        
        # Extract lock info from input_schema
        input_schemas = status_data.get("input_schema", [])
        if input_schemas:
            lock_info = input_schemas[0]
            print(f"\nLock ID: {lock_info.get('lock_id')}")
        break

    if job_status in ("completed", "failed"):
        print(f"\nJob {job_status}:")
        pprint(status_data)
        break

    time.sleep(1)
else:
    print("Timeout waiting for awaiting_input status")
# Out:
# [1/180] Status: awaiting_payment
# [2/180] Status: awaiting_payment
# [3/180] Status: awaiting_payment
# [4/180] Status: awaiting_payment
# [5/180] Status: awaiting_payment
# [6/180] Status: awaiting_payment
# [7/180] Status: awaiting_payment
# [8/180] Status: awaiting_payment
# [9/180] Status: awaiting_payment
# [10/180] Status: awaiting_payment
# [11/180] Status: awaiting_payment
# [12/180] Status: awaiting_payment
# [13/180] Status: awaiting_payment
# [14/180] Status: awaiting_payment
# [15/180] Status: awaiting_payment
# [16/180] Status: awaiting_payment
# [17/180] Status: awaiting_payment
# [18/180] Status: awaiting_payment
# [19/180] Status: awaiting_payment
# [20/180] Status: awaiting_payment
# [21/180] Status: awaiting_payment
# [22/180] Status: awaiting_payment
# [23/180] Status: awaiting_payment
# [24/180] Status: awaiting_payment
# [25/180] Status: awaiting_payment
# [26/180] Status: awaiting_payment
# [27/180] Status: awaiting_payment
# [28/180] Status: awaiting_payment
# [29/180] Status: awaiting_payment
# [30/180] Status: awaiting_payment
# [31/180] Status: awaiting_payment
# [32/180] Status: awaiting_payment
# [33/180] Status: awaiting_payment
# [34/180] Status: awaiting_payment
# [35/180] Status: awaiting_payment
# [36/180] Status: awaiting_payment
# [37/180] Status: awaiting_payment
# [38/180] Status: awaiting_payment
# [39/180] Status: awaiting_payment
# [40/180] Status: awaiting_payment
# [41/180] Status: awaiting_payment
# [42/180] Status: awaiting_payment
# [43/180] Status: awaiting_payment
# [44/180] Status: awaiting_payment
# [45/180] Status: awaiting_payment
# [46/180] Status: awaiting_payment
# [47/180] Status: awaiting_payment
# [48/180] Status: awaiting_payment
# [49/180] Status: awaiting_payment
# [50/180] Status: awaiting_payment
# [51/180] Status: awaiting_payment
# [52/180] Status: awaiting_payment
# [53/180] Status: awaiting_payment
# [54/180] Status: awaiting_payment
# [55/180] Status: awaiting_payment
# [56/180] Status: awaiting_payment
# [57/180] Status: awaiting_payment
# [58/180] Status: awaiting_payment
# [59/180] Status: awaiting_payment
# [60/180] Status: awaiting_payment
# [61/180] Status: awaiting_payment
# [62/180] Status: awaiting_payment
# [63/180] Status: awaiting_payment
# [64/180] Status: awaiting_payment
# [65/180] Status: awaiting_payment
# [66/180] Status: awaiting_payment
# [67/180] Status: awaiting_payment
# [68/180] Status: awaiting_payment
# [69/180] Status: awaiting_payment
# [70/180] Status: awaiting_payment
# [71/180] Status: awaiting_payment
# [72/180] Status: awaiting_payment
# [73/180] Status: awaiting_payment
# [74/180] Status: awaiting_payment
# [75/180] Status: awaiting_payment
# [76/180] Status: awaiting_payment
# [77/180] Status: awaiting_payment
# [78/180] Status: awaiting_payment
# [79/180] Status: awaiting_payment
# [80/180] Status: awaiting_payment
# [81/180] Status: awaiting_payment
# [82/180] Status: awaiting_payment
# [83/180] Status: awaiting_payment
# [84/180] Status: awaiting_payment
# [85/180] Status: awaiting_payment
# [86/180] Status: awaiting_payment
# [87/180] Status: awaiting_payment
# [88/180] Status: awaiting_payment
# [89/180] Status: awaiting_payment
# [90/180] Status: awaiting_payment
# [91/180] Status: awaiting_payment
# [92/180] Status: awaiting_payment
# [93/180] Status: awaiting_payment
# [94/180] Status: awaiting_payment
# [95/180] Status: awaiting_payment
# [96/180] Status: awaiting_input
#
# Job awaiting human input (HITL lock):
# {'error': None,
#  'identifier_from_purchaser': '3dcc8fa0662cf9bb236dcedb06',
#  'input_schema': [{'expires_at': 1765457052.529757,
#                    'input_data': [{'data': {'placeholder': 'Say hello...'},
#                                    'id': 'greeting',
#                                    'name': 'Your Greeting',
#                                    'type': 'text',
#                                    'validations': None}],
#                    'input_groups': None,
#                    'lock_id': '0c57857e-768c-48a6-80f3-843b2cc4ad7e'}],
#  'job_id': '693a91fb6dd65955fe1c6ccd',
#  'result': None,
#  'runtime': 111.71943712234497,
#  'started_at': 1765446140.8103628,
#  'status': 'awaiting_input',
#  'updated_at': 1765446252.5298}
#
# Lock ID: 0c57857e-768c-48a6-80f3-843b2cc4ad7e

# %%
resp = client.get(f"/sumi/status/{hitl_job_id}")
status_data = resp.json()
pprint(resp.json())
# Out:
# {'error': None,
#  'identifier_from_purchaser': '3dcc8fa0662cf9bb236dcedb06',
#  'input_schema': [{'expires_at': 1765457052.529757,
#                    'input_data': [{'data': {'placeholder': 'Say hello...'},
#                                    'id': 'greeting',
#                                    'name': 'Your Greeting',
#                                    'type': 'text',
#                                    'validations': None}],
#                    'input_groups': None,
#                    'lock_id': '0c57857e-768c-48a6-80f3-843b2cc4ad7e'}],
#  'job_id': '693a91fb6dd65955fe1c6ccd',
#  'result': None,
#  'runtime': 111.71943712234497,
#  'started_at': 1765446140.8103628,
#  'status': 'awaiting_input',
#  'updated_at': 1765446252.5298}

# %% [markdown]
# ### Get Lock Schema
#
# Use `/sumi/lock/{fid}/{lid}` to get the full input schema for the lock.

# %%
# Get lock schema via Sumi API
if lock_info:
    lock_id = lock_info.get("lock_id")
    
    resp = client.get(f"/sumi/lock/{hitl_job_id}/{lock_id}")
    print(f"Lock schema status: {resp.status_code}")
    lock_schema = resp.json()
    pprint(lock_schema)
    
    # Display the lock form fields
    if lock_schema.get("input_schema", {}).get("input_data"):
        print("\nLock Form Fields:")
        for field in lock_schema["input_schema"]["input_data"]:
            print(f"  • {field.get('name', field.get('id'))} ({field.get('type')})")
else:
    print("No lock info available")
# Out:
# Lock schema status: 200
# {'expires_at': 1765457052.529757,
#  'input_schema': {'input_data': [{'data': {'placeholder': 'Say hello...'},
#                                   'id': 'greeting',
#                                   'name': 'Your Greeting',
#                                   'type': 'text',
#                                   'validations': None}],
#                   'input_groups': None},
#  'job_id': '693a91fb6dd65955fe1c6ccd',
#  'prompt': 'greeting-lock',
#  'status': 'pending',
#  'status_id': '0c57857e-768c-48a6-80f3-843b2cc4ad7e'}
#
# Lock Form Fields:
#   • Your Greeting (text)

# %% [markdown]
# ### Provide Input (Release Lock)
#
# Submit the greeting input to release the lock and continue job execution.

# %%
# Provide input to release the lock
if lock_info:
    lock_id = lock_info.get("lock_id")
    
    resp = client.post(
        f"/sumi/lock/{hitl_job_id}/{lock_id}",
        json={
            "input_data": {
                "greeting": "Hello from HITL Demo!"
            }
        }
    )
    print(f"Provide input status: {resp.status_code}")
    provide_result = resp.json()
    pprint(provide_result)
else:
    print("No lock info available")
# Out:
# Provide input status: 201
# {'input_hash': '0790ebd49ba4dacd40f363559c944f282dc3a02941bdfd8053a4df0b72db1a56',
#  'status': 'success'}

# %% [markdown]
# ### Wait for Job Completion
#
# After the lock is released, the job will:
# 1. Process the greeting input
# 2. Generate the markdown result
# 3. Submit result hash to Masumi (payment finalization)
# 4. Complete with status `completed`

# %%
# Poll for job completion
for i in range(120):
    resp = client.get(f"/sumi/status/{hitl_job_id}")
    status_data = resp.json()
    job_status = status_data.get("status")

    print(f"[{i+1}/120] Status: {job_status}")

    if job_status == "completed":
        print("\n✓ Job completed successfully!")
        print("\nResult:")
        pprint(status_data.get("result"))
        break

    if job_status == "failed":
        print("\n✗ Job failed!")
        print("\nError:")
        print(status_data.get("error"))
        break

    time.sleep(1)
else:
    print("\nCurrent status:")
    pprint(status_data)
# Out:
# [1/120] Status: completed
#
# ✓ Job completed successfully!
#
# Result:
# {'Markdown': {'body': 'You say Hello from HITL Demo!, I say **goodbye**.'}}

# %% [markdown]
# ### Verify Payment Finalization
#
# Check the event stream for the `final_result` payment event.

# %%
# Check for payment finalization in event stream
final_payment = None
with client.stream("GET", f"/outputs/stream/{hitl_job_id}") as resp:
    for line in resp.iter_lines():
        if line and line.startswith("data:"):
            data_part = line[5:].strip()
            if ":" in data_part:
                ts, json_str = data_part.split(":", 1)
                try:
                    parsed = json_module.loads(json_str)
                    if "dict" in parsed:
                        d = parsed["dict"]
                        if d.get("step") == "final_result":
                            final_payment = d
                            print("Payment finalization event found:")
                            pprint(final_payment)
                except:
                    pass

if not final_payment:
    print("No payment finalization event found")
# Out:
# Payment finalization event found:
# {'resultHash': 'd3ca4ae36032e3090854468c314ad1869479be795e7164e0cb3f115b612f768d',
#  'step': 'final_result'}

# %% [markdown]
# ### HITL/Lock Payment Flow Summary
#
# | Step | Status | Description |
# |------|--------|-------------|
# | 1 | `running` | Job starts, validates inputs |
# | 2 | `awaiting_payment` | Payment initialized, waiting for `FundsLocked` |
# | 3 | `running` | Payment confirmed, job continues |
# | 4 | `awaiting_input` | Lock created, waiting for human input |
# | 5 | `running` | Lock released, processing input |
# | 6 | `completed` | Result generated, payment finalized |
#
# **Key Endpoints Used:**
# - `POST /sumi/{expose}/start_job` - Start job
# - `GET /sumi/status/{job_id}` - Poll status
# - `GET /sumi/lock/{fid}/{lid}` - Get lock schema
# - `POST /sumi/lock/{fid}/{lid}` - Provide input to release lock
# - `GET /outputs/stream/{job_id}` - Stream events (payment info)
